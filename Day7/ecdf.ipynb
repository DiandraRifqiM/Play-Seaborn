# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

pd.set_option('display.max_rows', None)

# %%
# Dataframe
df = pd.read_excel(r"D:\Python Course\Playing Seaborn\xlsx\supermarket_sales.xlsx")

# %%
# Basic ECDF
sns.ecdfplot(data=df, x='Total')
# Out:
# <Axes: xlabel='Total', ylabel='Proportion'>

# %%
# Categorical ECDF
sns.ecdfplot(data=df, x='Total', hue='Product line')
# Out:
# <Axes: xlabel='Total', ylabel='Proportion'>

# %%
# Stat ECDF
sns.ecdfplot(data=df, x='gross income', hue='Product line', stat='count')
# Out:
# <Axes: xlabel='gross income', ylabel='Count'>
